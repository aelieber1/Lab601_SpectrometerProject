# %% [markdown]
# # Lab Spectrometer Project

# %% [markdown]
# ## Image Processing Code

# %% [markdown]
# ### Tutorial Trials at Image Processing
# #### url: https://datacarpentry.org/image-processing/aio/index.html
# #### url: https://sites.google.com/a/uis.edu/grating-spectroscopy-workshop/simple-spectrum-extraction-tutorial

# %%
# import necessary libraries/packages
import numpy as np
import matplotlib.pyplot as plt
import ipympl
import imageio.v3 as iio
import sys
import skimage

#display images with pixel info
# %matplotlib widget 

#plot images within Jupyter notebook
# %matplotlib inline

# %% [raw]
# Pixels
# - discrete picture elements organized into rectangular arrays to store images
# - think of it as a single square point of colored light
# - each pizel is all one color
# - due to this format we often think of images as matrices of pixels

# %%
#image = iio.imread(uri="data/eight.tif")
#plt.imshow(image)

# %%
# import necessary libraries/packages
import numpy as np
import matplotlib.pyplot as plt
import ipympl
import imageio.v3 as iio
import skimage

#display images with pixel info
# %matplotlib widget 

#plot images within Jupyter notebook
# %matplotlib inline

# %%
img_path = "/Users/ashleylieber/Downloads/0_16.png"

# %%
""" 
Each row represents the specific pixel color, we can actually call each of 
the numbers individually. The numbers can then give us a representation of the 
image’s Red, Green, and Blue components. 
"""
img = plt.imread(img_path)
img
# Out:
# array([[[0.627451  , 0.627451  , 0.627451  , 1.        ],
#         [0.627451  , 0.627451  , 0.627451  , 1.        ],
#         [0.627451  , 0.627451  , 0.627451  , 1.        ],
#         ...,
#         [0.627451  , 0.627451  , 0.627451  , 1.        ],
#         [0.627451  , 0.627451  , 0.627451  , 1.        ],
#         [1.        , 1.        , 1.        , 1.        ]],
#
#        [[0.627451  , 0.627451  , 0.627451  , 1.        ],
#         [0.4117647 , 0.4117647 , 0.4117647 , 1.        ],
#         [0.4117647 , 0.4117647 , 0.4117647 , 1.        ],
#         ...,
#         [0.4117647 , 0.4117647 , 0.4117647 , 1.        ],
#         [0.8901961 , 0.8901961 , 0.8901961 , 1.        ],
#         [1.        , 1.        , 1.        , 1.        ]],
#
#        [[0.627451  , 0.627451  , 0.627451  , 1.        ],
#         [0.4117647 , 0.4117647 , 0.4117647 , 1.        ],
#         [0.        , 0.01568628, 0.04705882, 1.        ],
#         ...,
# ...

# %%
plt.imshow(img[:, 400:650])

# %%
img[:, 400:650]
# Out:
# array([[[0.627451  , 0.627451  , 0.627451  , 1.        ],
#         [0.627451  , 0.627451  , 0.627451  , 1.        ],
#         [0.627451  , 0.627451  , 0.627451  , 1.        ],
#         ...,
#         [0.627451  , 0.627451  , 0.627451  , 1.        ],
#         [0.627451  , 0.627451  , 0.627451  , 1.        ],
#         [0.627451  , 0.627451  , 0.627451  , 1.        ]],
#
#        [[0.4117647 , 0.4117647 , 0.4117647 , 1.        ],
#         [0.4117647 , 0.4117647 , 0.4117647 , 1.        ],
#         [0.4117647 , 0.4117647 , 0.4117647 , 1.        ],
#         ...,
#         [0.4117647 , 0.4117647 , 0.4117647 , 1.        ],
#         [0.4117647 , 0.4117647 , 0.4117647 , 1.        ],
#         [0.4117647 , 0.4117647 , 0.4117647 , 1.        ]],
#
#        [[0.02745098, 0.03921569, 0.05490196, 1.        ],
#         [0.03529412, 0.04313726, 0.05882353, 1.        ],
#         [0.02745098, 0.03529412, 0.05098039, 1.        ],
#         ...,
# ...

# %%
plt.hist(img.ravel(), bins=256, range=(0.0, 1.0), fc='k', ec='k') #calculating histogram
# Out:
# (array([8.84990e+04, 8.42420e+04, 9.06390e+04, 9.33810e+04, 8.84550e+04,
#         7.91290e+04, 6.73020e+04, 5.54360e+04, 4.48750e+04, 3.58780e+04,
#         2.82370e+04, 2.24930e+04, 1.75290e+04, 1.35560e+04, 1.01560e+04,
#         7.50400e+03, 5.31200e+03, 3.94000e+03, 2.94500e+03, 2.11100e+03,
#         1.74100e+03, 1.39100e+03, 1.20900e+03, 1.01300e+03, 9.08000e+02,
#         8.48000e+02, 8.02000e+02, 7.85000e+02, 7.76000e+02, 7.39000e+02,
#         6.82000e+02, 6.35000e+02, 6.10000e+02, 5.53000e+02, 5.14000e+02,
#         5.02000e+02, 4.05000e+02, 4.10000e+02, 3.68000e+02, 2.70000e+02,
#         2.53000e+02, 2.15000e+02, 1.98000e+02, 1.46000e+02, 1.42000e+02,
#         1.15000e+02, 9.00000e+01, 1.01000e+02, 8.70000e+01, 8.60000e+01,
#         8.10000e+01, 7.90000e+01, 9.10000e+01, 7.00000e+01, 6.20000e+01,
#         6.70000e+01, 7.50000e+01, 6.10000e+01, 6.30000e+01, 6.40000e+01,
#         5.80000e+01, 6.40000e+01, 6.20000e+01, 5.90000e+01, 6.10000e+01,
# ...

# %%
import imageio.v2 as imageio
import matplotlib.pyplot as plt
# %matplotlib inline

pic = imageio.imread(img_path)
plt.figure(figsize = (15,15))

plt.imshow(pic)

# %%
print('Type of the image : ' , type(pic))
print()
print('Shape of the image : {}'.format(pic.shape))
print('Image Hight {}'.format(pic.shape[0]))
print('Image Width {}'.format(pic.shape[1]))
print('Dimension of Image {}'.format(pic.ndim))
# Out:
# Type of the image :  <class 'imageio.core.util.Array'>
#
# Shape of the image : (254, 1157, 4)
# Image Hight 254
# Image Width 1157
# Dimension of Image 3

# %%
print('Image size {}'.format(pic.size))
print('Maximum RGB value in this image {}'.format(pic.max()))
print('Minimum RGB value in this image {}'.format(pic.min()))
# Out:
# Image size 1175512
# Maximum RGB value in this image 255
# Minimum RGB value in this image 0

# %%
'''
Let's pick a specific pixel located at 100 th Rows and 50 th Column. 
And view the RGB value gradually. 
'''
pic[ 100, 50 ]
# Out:
# Array([  0,   5,   4, 255], dtype=uint8)

# %%
# A specific pixel located at Row : 100 ; Column : 50 
# Each channel's value of it, gradually R , G , B
print('Value of only R channel {}'.format(pic[ 100, 50, 0]))
print('Value of only G channel {}'.format(pic[ 100, 50, 1]))
print('Value of only B channel {}'.format(pic[ 100, 50, 2]))
# Out:
# Value of only R channel 0
# Value of only G channel 5
# Value of only B channel 4

# %%
plt.title('R channel')
plt.ylabel('Height {}'.format(pic.shape[0]))
plt.xlabel('Width {}'.format(pic.shape[1]))

plt.imshow(pic[ : , : , 0])
plt.show()

# %%
plt.title('G channel')
plt.ylabel('Height {}'.format(pic.shape[0]))
plt.xlabel('Width {}'.format(pic.shape[1]))

plt.imshow(pic[ : , : , 1])
plt.show()

# %%
plt.title('B channel')
plt.ylabel('Height {}'.format(pic.shape[0]))
plt.xlabel('Width {}'.format(pic.shape[1]))

plt.imshow(pic[ : , : , 2])
plt.show()

# %%
fig, ax = plt.subplots(nrows = 1, ncols=3, figsize=(15,5))

for c, ax in zip(range(3), ax):
    
    # create zero matrix
    split_img = np.zeros(pic.shape, dtype="uint8") # 'dtype' by default: 'numpy.float64'
    
    # assing each channel 
    split_img[ :, :, c] = pic[ :, :, c]
    
    # display each channel
    ax.imshow(split_img)
